# %% [markdown]
# #  <center> <font color='purple'> 🏠 Housing Price Prediction with  Machine Learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# # Housing Price Prediction Case Study

# %% [markdown]
# ## <b> <font color="#1E90FF"> <b> Problem Statement :

# %% [markdown]
# Consider a real estate company that has a dataset containing the prices of properties in the Delhi region. It wishes to use the data to optimise the sale prices of the properties based on important factors such as area, bedrooms, parking, etc.

# %% [markdown]
# Essentially, the company wants —

# %% [markdown]
# * To identify the variables affecting house prices, e.g. area, number of rooms, bathrooms, etc.
#
#
# * To create a linear model that quantitatively relates house prices with variables such as number of rooms, area, number of bathrooms, etc.
#
#
# * To know the accuracy of the model, i.e. how well these variables can predict house prices.

# %% [markdown]
# ## <b> <font color="#1E90FF"> Data :

# %% [markdown]
# Use housing dataset.

# %% [markdown]
# ***

# %% [markdown]
# # Table of Contents :

# %% [markdown]
# <a href="#-1.-Importing-Libraries-" style="text-decoration: none;"> 1. <b> <font color="#1E90FF">
#  Importing Libraries <a class="anchor" id="Importing Libraries" rel="nofollow">
#
# <a href="#-2.-Here-we-read-the-data-using-read-csv-file" style="text-decoration: none;"> 2. <b> <font color="#1E90FF">
# Here we read the data using read csv file</font>
#
# <a href="#-3.-Styles-of-tables-or-data-using-pandas" style="text-decoration: none;"> 3. <b> <font color="#1E90FF">
#  Styles of tables or data using pandas</font>
#
# <a href="#-4.-Hence-we-dont-wont-date-and-statezip-we-drop-them-using-drop" style="text-decoration: none;"> 4. <b> <font color="#1E90FF"> Hence we dont wont date and statezip we drop them using drop</font>
#
# <a href="#-5.-Were-we-have-convert-into-int-or-float-data-,-we-are-using-Regression-problem" style="text-decoration: none;"> 5. <b> <font color="#1E90FF"> Were we have convert into int or float data , we are using Regression problem</font>
#
# <a href="#-6.-Hence-we-have-different-data-in-strings-we-can-converts-into-birany-data" style="text-decoration: none;"> 6. <b> <font color="#1E90FF"> Hence we have different data in strings we can converts into birany data</font>
#
# <a href="#-7.-If-we-have-null-values-we-use-replace-or-mean-or-median" style="text-decoration: none;"> 7. <b> <font color="#1E90FF"> If we have null values we use replace or mean or median</font>
#
# <a href="#-8.-Data-Visulization" style="text-decoration: none;"> 8. <b> <font color="#1E90FF"> Data Visulization</font>
#
# <a href="#-9.-hence-we-are-100-%-accracy" style="text-decoration: none;"> 9. <b> <font color="#1E90FF"> Hence we are 100 % accracy</font>

# %% [markdown]
# ***

# %% [markdown]
# <a class="anchor" id="chapter1"></a>

# %% [markdown]
#   #  <font color='blue'> 1. Importing Libraries <a class="anchor" id="Importing Libraries"></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # <font color='blue'> 2. Here we read the data using read csv file

# %%
house_data=pd.read_csv(r"C:\Users\userkk\Downloads\Housing Price Prediction/data.csv")

# %%
house_data.head() # lets see top 5 in our data
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %% [markdown]
# <a class="anchor" id="chapter3"></a>

# %% [markdown]
# # <font color='blue'> 3. Styles of tables or data using pandas

# %%
# house_data.style.highlight_max() showing max values in every colums by highling color
#house_data.style.highlight_min() #showinh min values in every colums by hihhling color
# house_data.style.highlight_null(null_color="green") #showinh null values in every colums by green color

# %%
house_data.describe().transpose() #lets decribe the data
# Out:
#                 count           mean            std     min        25%  \
# price          4600.0  551962.988473  563834.702547     0.0  322875.00
# bedrooms       4600.0       3.400870       0.908848     0.0       3.00
# bathrooms      4600.0       2.160815       0.783781     0.0       1.75
# sqft_living    4600.0    2139.346957     963.206916   370.0    1460.00
# sqft_lot       4600.0   14852.516087   35884.436145   638.0    5000.75
# floors         4600.0       1.512065       0.538288     1.0       1.00
# waterfront     4600.0       0.007174       0.084404     0.0       0.00
# view           4600.0       0.240652       0.778405     0.0       0.00
# condition      4600.0       3.451739       0.677230     1.0       3.00
# sqft_above     4600.0    1827.265435     862.168977   370.0    1190.00
# sqft_basement  4600.0     312.081522     464.137228     0.0       0.00
# yr_built       4600.0    1970.786304      29.731848  1900.0    1951.00
# ...

# %%
house_data.shape # Hence we have 4600 rows and 18 columns
# Out:
# (4600, 18)

# %%
house_data.columns #the name of the colums
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %% [markdown]
# <a class="anchor" id="chapter4"></a>

# %% [markdown]
# # <font color='blue'> 4. Hence we dont wont date and statezip we drop them using drop

# %%
house_data = house_data.drop('date',axis=1)
house_data = house_data.drop('statezip',axis=1)

# %%
house_data.dtypes # Hence it is regression problem we have to check the datatypes of the data
# Out:
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# country           object
# dtype: object

# %% [markdown]
# <a class="anchor" id="chapter5"></a>

# %% [markdown]
# # <font color='blue'> 5. Were we have convert into int or float data , we are using Regression problem

# %%
house_data["price"]=house_data["price"].astype(int)
house_data["bedrooms"]=house_data["price"].astype(int)
house_data["bathrooms"]=house_data["price"].astype(int)
house_data["floors"]=house_data["price"].astype(int)

# %% [markdown]
# <a class="anchor" id="chapter6"></a>

# %% [markdown]
# # <font color='blue'> 6. Hence we have different data in strings we can converts into birany data

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
house_data["street"]=LE.fit_transform(house_data["street"])
house_data["city"]=LE.fit_transform(house_data["city"])
house_data["country"]=LE.fit_transform(house_data["country"])

# %%
house_data.dtypes
# Out:
# price            int32
# bedrooms         int32
# bathrooms        int32
# sqft_living      int64
# sqft_lot         int64
# floors           int32
# waterfront       int64
# view             int64
# condition        int64
# sqft_above       int64
# sqft_basement    int64
# yr_built         int64
# yr_renovated     int64
# street           int32
# city             int32
# country          int32
# dtype: object

# %%
house_data.isnull().sum() # hence we have every thing int or flaot we have check the null values
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# country          0
# dtype: int64

# %% [markdown]
#   <a class="anchor" id="chapter7"></a>

# %% [markdown]
# # <font color='blue'> 7. If we have null values we use replace or mean or median

# %% [markdown]
#   <a class="anchor" id="chapter8"></a>

# %% [markdown]
# # <font color='blue'> 8. Data Visulization

# %%
import matplotlib.pyplot as plp
import seaborn as sns

# %%
sns.set(style="darkgrid")
sns.regplot(x=house_data['yr_built'], y= house_data["price"])
# Out:
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %%
sns.displot(house_data["bedrooms"],bins=10)

# %%
house_data.hist(figsize=(15,20))
plp.show()

# %%
plp.figure(figsize=(15,20))
sns.barplot(data=house_data,y='city',x='price',orient="h3")
# Out:
# <AxesSubplot:xlabel='price', ylabel='city'>

# %%
plp.figure(figsize=(30,45))
sns.barplot(x=house_data["yr_renovated"],y=house_data["price"])
# Out:
# <AxesSubplot:xlabel='yr_renovated', ylabel='price'>

# %%
plp.figure(figsize=(8,6))
sns.set_context('paper',font_scale=1.4)
house_data2=house_data.corr()
sns.heatmap(house_data2,cmap="icefire")
# Out:
# <AxesSubplot:>

# %%
X = house_data.drop('price',axis =1).values
y = house_data['price'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.linear_model import LinearRegression 
regg=LinearRegression()
regg.fit(X_train, y_train)
y_pred=regg.predict(X_test)

# %%
from sklearn.metrics import r2_score
acc=r2_score(y_test,y_pred)
acc
# Out:
# 1.0

# %% [markdown]
#   <a class="anchor" id="chapter9"></a>

# %%
mlr = LinearRegression()
mlr.fit(X_train, y_train)
y_pred = mlr.predict(X_test)
r2_mlr = r2_score(y_test, y_pred_mlr)

# %%
from sklearn.metrics import r2_score
acc=r2_score(y_test,y_pred)
acc
# Out:
# 1.0

# %% [markdown]
# <a class="anchor" id="chapter9"></a>

# %% [markdown]
# # <font color='green'> 9. Hence we are 100 % accracy
